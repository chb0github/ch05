# %% [markdown]
# # Exercise 5-4: Get data from a Stata file

# %%
import pandas as pd
import sys
sys.path.append('..')
from utils import unzip_file

# Check if the zip file exists, if not we might need to download it but the instructions say it's unzipped.
# However, the previous cell unzips it. Let's make sure we use the right path.

files = unzip_file('gss_stata_with_codebook.zip')

# Find the .DTA file in the list of extracted files
stata_file = [f for f in files if f.endswith('.DTA')][0]

df = pd.read_stata(stata_file, convert_categoricals=False)
df.head()
# Out:
#    year  id  wrkstat  hrs1  hrs2  evwork    occ  prestige  wrkslf  wrkgovt  \
# 0  1972   1      1.0   NaN   NaN     NaN  205.0      50.0     2.0      NaN
# 1  1972   2      5.0   NaN   NaN     1.0  441.0      45.0     2.0      NaN
# 2  1972   3      2.0   NaN   NaN     NaN  270.0      44.0     2.0      NaN
# 3  1972   4      1.0   NaN   NaN     NaN    1.0      57.0     2.0      NaN
# 4  1972   5      7.0   NaN   NaN     1.0  385.0      40.0     2.0      NaN
#
#    ...  neisafe  rlooks  rgroomed  rweight  rhlthend  wtss  wtssnr  wtssall  \
# 0  ...      NaN     NaN       NaN      NaN       NaN   1.0     1.0   0.4446
# 1  ...      NaN     NaN       NaN      NaN       NaN   1.0     1.0   0.8893
# 2  ...      NaN     NaN       NaN      NaN       NaN   1.0     1.0   0.8893
# 3  ...      NaN     NaN       NaN      NaN       NaN   1.0     1.0   0.8893
# 4  ...      NaN     NaN       NaN      NaN       NaN   1.0     1.0   0.8893
#
#    vstrat  vpsu
# 0     NaN   NaN
# 1     NaN   NaN
# 2     NaN   NaN
# 3     NaN   NaN
# 4     NaN   NaN
#
# [5 rows x 6110 columns]

# %% [markdown]
# ## Build a DataFrame for the metadata

# %%
import pyreadstat

# get the metadata container
df, metadata = pyreadstat.read_dta(stata_file, encoding='cp1252')

# %%
# print the attributes from DataFrame
print(f"Number of columns: {metadata.number_columns}")
print(f"Number of rows: {metadata.number_rows}")
print(f"Column names: {', '.join(metadata.column_names[:10])}") # Show first 10
# Out:
# Number of columns: 6110
# Number of rows: 64814
# Column names: year, id, wrkstat, hrs1, hrs2, evwork, occ, prestige, wrkslf, wrkgovt

# %%
# build a DataFrame from the metadata
df = pd.DataFrame(metadata.column_labels, index=metadata.column_names)
df.head()
metadata_df = pd.DataFrame(metadata.column_labels, index=metadata.column_names, columns=['description'])
metadata_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 df = pd.DataFrame(metadata.column_labels, index=metadata.column_names)
#       3 df.head()
# ----> 4 metadata_df = pd.DataFrame(metadata.column_labels, index=metadata.column_names, columns=metadata.column_names)
#       5 metadata_df.head()
#
# File ~/dev/mine/belcol/DEV228/ch05/.venv/lib/python3.14/site-packages/pandas/core/frame.py:852, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     845         mgr = arrays_to_mgr(
#     846             arrays,
#     847             columns,
#     848             index,
#     849             dtype=dtype,
#     850         )
#     851     else:
# --> 852         mgr = ndarray_to_mgr(
#     853             data,
#     854             index,
#     855             columns,
#     856             dtype=dtype,
#     857             copy=copy,
#     858         )
#     859 else:
#     860     mgr = dict_to_mgr(
#     861         {},
#     862         index,
#     863         columns if columns is not None else default_index(0),
#     864         dtype=dtype,
#     865     )
#
# File ~/dev/mine/belcol/DEV228/ch05/.venv/lib/python3.14/site-packages/pandas/core/internals/construction.py:286, in ndarray_to_mgr(values, index, columns, dtype, copy)
#     281 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     282 index, columns = _get_axes(
#     283     values.shape[0], values.shape[1], index=index, columns=columns
#     284 )
# --> 286 _check_values_indices_shape_match(values, index, columns)
#     288 values = values.T
#     290 # if we don't have a dtype specified, then try to convert objects
#     291 # on the entire block; this is to convert if we have datetimelike's
#     292 # embedded in an object type
#
# File ~/dev/mine/belcol/DEV228/ch05/.venv/lib/python3.14/site-packages/pandas/core/internals/construction.py:359, in _check_values_indices_shape_match(values, index, columns)
#     357 passed = values.shape
#     358 implied = (len(index), len(columns))
# --> 359 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (6110, 1), indices imply (6110, 6110)

# %% [markdown]
# ## Read the data into a DataFrame

# %%
# read at least 5 columns from the stata file into a DataFrame
df_subset = pd.read_stata(stata_file, columns=['year', 'id', 'age', 'sex', 'race'], convert_categoricals=False)
df_subset.head()
# Out:
#    year  id   age  sex  race
# 0  1972   1  23.0    2     1
# 1  1972   2  70.0    1     1
# 2  1972   3  48.0    2     1
# 3  1972   4  27.0    2     1
# 4  1972   5  61.0    2     1

# %% [markdown]
# # Exercise 5-3: Get data from a database

# %%
import sys
import os
import pandas as pd
import sqlite3

sys.path.append('..')
from utils import unzip_file, download_file
# doesn't always work
fires_url = 'https://cdn.inst-fs-iad-prod.inscloudgate.net/a366ac4c-fe94-46f4-87ee-8911dd9a4a99/RDS-2013-0009.4_SQLITE.zip?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii9hMzY2YWM0Yy1mZTk0LTQ2ZjQtODdlZS04OTExZGQ5YTRhOTkvUkRTLTIwMTMtMDAwOS40X1NRTElURS56aXAiLCJ0ZW5hbnQiOiJjYW52YXMiLCJpYXQiOjE3NzA0ODUwOTMsImV4cCI6MTc3MDU3MTQ5MywianRpIjoiZTY0YzEzZGUtOWIyOC00OThhLWFmMTgtMDY5ODU5ODA1NjZiIn0.nvMxfXSQx4C91bY_TDGPs1fGia2pDufQjOzTOeEdFzaqc66Gqk0r96-MYGfIQt9ECbZDA5DVvAE6EEHcqPnAiQ&download=1&content_type=application%2Fx-zip-compressed'
db = 'RDS-2013-0009.4_SQLITE.zip'
if not os.path.exists(db):
    db = download_file(fires_url)

conn = sqlite3.connect(db)
cursor = conn.cursor()

# Get all table names
tables = cursor.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
print(tables)

# Read SQL query directly into a DataFrame
df = pd.read_sql_query("SELECT * FROM sqlite_master", conn)

# Or read an entire table
df = pd.read_sql_table('sqlite_master', conn)
# Out:
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 23
#      19 print(tables)
#      22 # Print table names
# ---> 23 for table, _ in tables:
#      24     print(table)
#      25 # Read SQL query directly into a DataFrame
#
# File ~/Applications/PyCharm.app/Contents/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:888, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     885             stop = False
#     887 if plugin_stop:
# --> 888     stopped_on_plugin = plugin_manager.stop(main_debugger, frame, event, self._args, stop_info, arg, step_cmd)
#     889 elif stop:
#     890     if is_line:
#
# File ~/Applications/PyCharm.app/Contents/plugins/python-ce/helpers/jupyter_debug/pydev_jupyter_plugin.py:185, in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
# ...

# %%
import sqlite3
import pandas as pd

# Connect to the database
conn = sqlite3.connect(sql_file)

# %%
## Run queries against the database

# %%
# Example query: list tables
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
print(tables)

# %% [markdown]
# ## Read the results of a SQL query into a DataFrame

# %%
# Example query: read first 5 rows from a table (assuming 'Fires' table exists)
# You might need to adjust the table name based on the 'tables' output above
df = pd.read_sql_query("SELECT * FROM Fires LIMIT 5;", conn)
df.head()
